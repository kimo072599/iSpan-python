# %% [markdown]
# ##### 將 data.txt 的資料分類成另外三個檔案，分別為 cc.txt 、 css.txt 、 c.txt

# %%
# with open(file="data.txt", mode="r", encoding="utf-8") as f:
#     doc_list = f.readlines()
# for doc in doc_list:
#     file_list.append(doc)

# cc_txt_list = []
# css_txt_list = []
# c_txt_list = []
# for file_name in file_list:
#     if ".css\n" in file_name:
#         css_txt_list.append(file_name)
#     if ".cc\n" in file_name:
#         cc_txt_list.append(file_name)
#     if ".c\n" in file_name:
#         c_txt_list.append(file_name)
# print(css_txt_list)
# print(cc_txt_list)
# print(c_txt_list)

with open(file="data.txt", mode="r", encoding="utf-8") as f:
    file_list = [doc for doc in f.readlines()]
for file_name in file_list:
    if ".css\n" in file_name:
        with open(file="./css.txt", mode="a", encoding="utf-8") as f:
            f.write(file_name)
    if ".cc\n" in file_name:
        with open(file="./cc.txt", mode="a", encoding="utf-8") as f:
            f.write(file_name)
    if ".c\n" in file_name:
        with open(file="./c.txt", mode="a", encoding="utf-8") as f:
            f.write(file_name)

# %%
# 老師版
def insert_data(file_path, info):
    with open(file_path, 'a') as f:
        f.write(info)

with open('data.txt', 'r') as f:
    data_list = f.readlines()

for data in data_list:
    data_without_n = data.strip('\n')
    if data_without_n.split('.')[-1] == 'css':
        insert_data('css.txt', data)
    elif data_without_n.split('.')[-1] == 'cc':
        insert_data('cc.txt', data)
    elif data_without_n.split('.')[-1] == 'c':
        insert_data('c.txt', data)
